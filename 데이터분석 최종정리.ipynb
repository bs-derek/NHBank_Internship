# %%
# 데이터 구성 : Series, DataFrame
import pandas as pd
# 데이터 시각화
import matplotlib.pyplot as plt
import matplotlib
# export_graphviz: 나무 구조 생성 및 저장
from sklearn.tree import export_graphviz
# graphviz : 나무 구조 시각화 (.dot 확장자 파일 불러오기 등)
import graphviz

# 데이터 분할 : train, test
from sklearn.model_selection import train_test_split
# 분류 Decision Tree
from sklearn.tree import DecisionTreeClassifier
# 최적 모델, 파라미터 탐색
from sklearn.model_selection import GridSearchCV
# 모델 성능 평가
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from lightgbm import LGBMClassifier, plot_importance


# 맑은 고딕 적용
# font_path = 'C:/Users/Beomsu/AppData/Local/Microsoft/Windows/Fonts/NanumSquareR.ttf'
# font_name = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
# matplotlib.rc('font', family = font_name)
# from matplotlib import font_manager,rc

# %matplotlib inline

from tqdm.notebook import tqdm

# %% [markdown]
# ## Raw Data (초도모델용) -> String Data 다 빠져있음!
#
# 초도모델 데이터에 변수를 하나씩 추가하는 방향으로 진행

# %%
df_raw = pd.read_csv('./raw_data2.csv.gz', encoding='euc-kr', engine='python')

# %%
df_raw.head(5)
# Out:
#    label_소명여부  사무소코드       사용일      시간  업종코드     금액        br_x       br_y  \
# 0           0   2066  20180605  125707  2104   9000  126.827489  37.560405
# 1           0   2066  20190906  172408  2104   7500  126.827489  37.560405
# 2           0   2066  20180430   82058  2104  44000  126.827489  37.560405
# 3           0   2066  20181109  154730  2104  39000  126.827489  37.560405
# 4           0   2066  20190327  165736  2104  26000  126.827489  37.560405
#
#             x          y  ...  사용_월  사용_일  사용요일_금  사용요일_목  사용요일_수  사용요일_월  \
# 0  126.830435  37.559767  ...     6     5       0       0       0       0
# 1  126.830435  37.559767  ...     9     6       1       0       0       0
# 2  126.830435  37.559767  ...     4    30       0       0       0       1
# 3  126.830435  37.559767  ...    11     9       1       0       0       0
# 4  126.830435  37.559767  ...     3    27       0       0       1       0
#
#    사용요일_일  사용요일_토  사용요일_화      개인id
# 0       0       0       1  kkikkk9b
# 1       0       0       0  9fbkk666
# 2       0       0       0  bfibb5f5
# 3       0       0       0  bfibb5f5
# 4       0       0       0  bfibb5f5
#
# [5 rows x 25 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924521 entries, 0 to 1924520
# Data columns (total 25 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   label_소명여부  int64
#  1   사무소코드       int64
#  2   사용일         int64
#  3   시간          int64
#  4   업종코드        int64
#  5   금액          int64
#  6   br_x        float64
#  7   br_y        float64
#  8   x           float64
#  9   y           float64
#  10  distance    float64
#  11  사용_시        int64
#  12  사용_분        int64
#  13  사용_초        int64
#  14  사용_년        int64
#  15  사용_월        int64
#  16  사용_일        int64
#  17  사용요일_금      int64
#  18  사용요일_목      int64
#  19  사용요일_수      int64
#  20  사용요일_월      int64
#  21  사용요일_일      int64
#  22  사용요일_토      int64
#  23  사용요일_화      int64
#  24  개인id        object
# dtypes: float64(5), int64(19), object(1)
# memory usage: 367.1+ MB

# %% [markdown]
# ## Temp Data (초도모델용 데이터 전처리 작업 이전의 데이터) -> String Data 포함!

# %%
df_temp = pd.read_csv("./raw_data1.csv.gz", engine = "python", encoding='euc-kr')

# %%
df_temp.head(5)
# Out:
#    label_소명여부      개인id  사무소코드   사무소명 소명대상_구분       사용일      시간  \
# 0           0  kkikkk9b   2066  마곡역지점      no  20180605  125707
# 1           0  9fbkk666   2066  마곡역지점      no  20190906  172408
# 2           0  bfibb5f5   2066  마곡역지점      no  20180430  082058
# 3           0  bfibb5f5   2066  마곡역지점      no  20181109  154730
# 4           0  bfibb5f5   2066  마곡역지점      no  20190327  165736
#
#                가맹점명  업종코드        업종명  ...           x          y 사용요일  \
# 0  샐모닝 (Salmorning)  2104  외식유흥관련가맹점  ...  126.830435  37.559767    화
# 1  샐모닝 (Salmorning)  2104  외식유흥관련가맹점  ...  126.830435  37.559767    금
# 2  샐모닝 (Salmorning)  2104  외식유흥관련가맹점  ...  126.830435  37.559767    월
# 3  샐모닝 (Salmorning)  2104  외식유흥관련가맹점  ...  126.830435  37.559767    금
# 4  샐모닝 (Salmorning)  2104  외식유흥관련가맹점  ...  126.830435  37.559767    수
#
#    distance 사용_시 사용_분 사용_초  사용_년 사용_월 사용_일
# 0  0.003014   12   57   07  2018    6    5
# 1  0.003014   17   24   08  2019    9    6
# 2  0.003014   08   20   58  2018    4   30
# 3  0.003014   15   47   30  2018   11    9
# 4  0.003014   16   57   36  2019    3   27
#
# [5 rows x 34 columns]

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924521 entries, 0 to 1924520
# Data columns (total 34 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   label_소명여부   int64
#  1   개인id         object
#  2   사무소코드        int64
#  3   사무소명         object
#  4   소명대상_구분      object
#  5   사용일          int64
#  6   시간           object
#  7   가맹점명         object
#  8   업종코드         int64
#  9   업종명          object
#  10  가맹점세부업종명     object
#  11  금액           int64
#  12  가맹점주소        object
#  13  사무소주소        object
#  14  br_address0  object
#  15  br_address1  object
#  16  br_address2  object
#  17  br_address3  object
#  18  address0     object
#  19  address1     object
#  20  address2     object
#  21  address3     object
#  22  br_x         float64
#  23  br_y         float64
#  24  x            float64
#  25  y            float64
#  26  사용요일         object
#  27  distance     float64
#  28  사용_시         object
#  29  사용_분         object
#  30  사용_초         object
#  31  사용_년         int64
#  32  사용_월         int64
#  33  사용_일         int64
# dtypes: float64(5), int64(8), object(21)
# memory usage: 499.2+ MB

# %%
df_raw['개인id'] = df_temp['개인id']

# %% [markdown]
# ### 개인 id별 분석을 위해 id가 없는 경우 데이터 삭제

# %%
df_raw = df_raw[df_raw['개인id']!='no']

# %%
df_temp = df_temp[df_temp['개인id']!='no']

# %%
df_raw.reset_index(drop = True, inplace = True)
df_temp.reset_index(drop = True, inplace = True)

# %%
df_raw.drop(['개인id'], axis='columns', inplace=True)

# %% [markdown]
# ## 파생변수 생성 부분

# %% [markdown]
# ###  id별 소명건수 2회 이상 여부 파생변수 생성

# %%
df_label1 = df_temp[df_temp['label_소명여부']==1]

# %%
df_label1.reset_index(drop = True, inplace=True)

# %%
from collections import defaultdict
id_dict = defaultdict(int)

for i in tqdm(range(len(df_label1))) :
    id_dict[df_temp['개인id'][i]] += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12167.0), HTML(value='')))

# %%
temp = []
for i in tqdm(range(len(df_temp))):
    if df_temp['개인id'][i] in id_dict :
        temp.append(id_dict[df_temp['개인id'][i]])
    else :
        temp.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['가중치'] = temp

# %% [markdown]
# ### 금액 50만원 이상 여부 파생변수 생성

# %%
df_raw['50만원이상'] = (df_raw['금액'] > 500000).astype(int)

# %% [markdown]
# ### 금액 10만원 이상 여부 파생변수 생성

# %%
df_raw['10만원이상'] = (df_raw['금액'] > 100000).astype(int)

# %% [markdown]
# ### 공휴일 여부 파생변수 생성

# %%
holiday_list = [20170127, 20170130, 20170301, 20170503, 20170505, 20170509, 20170606, 20170815, 20171002, 
20171003, 20171004, 20171005, 20171006, 20171009, 20171225, 20180101, 20180215, 20180216, 
20180301, 20180507, 20180522, 20180606, 20180613, 20180815, 20180924, 20180925, 20180926, 
20181003, 20181009, 20181225, 20190101, 20190204, 20190205, 20190206, 20190301, 20190506, 
20190606, 20190815, 20190912, 20190913, 20191003, 20191009, 20191225, 20200101, 20200124, 
20200127, 20200415, 20200430, 20200505, 20200817]

# %%
in_holiday_list = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['사용일'][i] in holiday_list :
        in_holiday_list.append(1)
    else :
        in_holiday_list.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['연휴여부'] = in_holiday_list

# %% [markdown]
# ### 연휴 하루 전후 포함 여부 파생변수 생성

# %%
holiday_list_plus = []
for i in tqdm(range(len(holiday_list))) :
    holiday_list_plus.append(holiday_list[i]-1)
    holiday_list_plus.append(holiday_list[i])
    holiday_list_plus.append(holiday_list[i]+1)
holiday_list_plus = list(set(holiday_list_plus))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))

# %%
holiday_list_plus.remove(20170300); holiday_list_plus.append(20170228)
holiday_list_plus.remove(20190300); holiday_list_plus.append(20190228)
holiday_list_plus.remove(20180100); holiday_list_plus.append(20171230)
holiday_list_plus.remove(20200100); holiday_list_plus.append(20191231)
holiday_list_plus.remove(20180300); holiday_list_plus.append(20180228)
holiday_list_plus.remove(20190100); holiday_list_plus.append(20181231)
holiday_list_plus.remove(20200431); holiday_list_plus.append(20200501)

# %%
in_holiday_list_plus = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['사용일'][i] in holiday_list_plus :
        in_holiday_list_plus.append(1)
    else :
        in_holiday_list_plus.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['연휴전후여부'] = in_holiday_list_plus

# %% [markdown]
# ### 룰 기반 모니터링에 필터링 걸렸는지 여부(소명대상_구분)

# %%
temp = []
for i in tqdm(range(len(df_temp))):
    if df_temp['소명대상_구분'][i] == 'no' :
        temp.append(0)
    else :
        temp.append(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['소명대상_구분'] = temp

# %% [markdown]
# ### 업종별 이상거래 비율(Target Encoding) -> 가장 기본적인 방법(mean)

# %%
temp = df_temp.groupby('업종명')['label_소명여부'].mean()

# %%
temp_list = []

for i in tqdm(range(len(df_temp))):
    temp_list.append(temp[df_temp['업종명(mean)'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['업종명(mean)'] = temp_list

# %% [markdown]
# ### 22시 ~ 07시 사이 사용 여부

# %%
temp = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['시간'][i] >= 220000 or df_raw['시간'][i] < 70000 :
        temp.append(1)
    else :
        temp.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['22시이후'] = temp

# %% [markdown]
# ### 주말 사용 여부

# %%
temp = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['사용요일_토'][i] == 1 or df_raw['사용요일_일'][i] == 1 :
        temp.append(1)
    else :
        temp.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['주말여부'] = temp

# %% [markdown]
# ### 세부업종명별 이상거래 비율(Target Encoding) -> 가장 기본적인 방법(mean)

# %%
temp_list = []

for i in tqdm(range(len(df_temp))):
    temp_list.append(temp[df_temp['가맹점세부업종명'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
temp = df_temp.groupby('가맹점세부업종명')['label_소명여부'].mean()

# %%
df_raw['세부업종명(mean)'] = temp_list

# %% [markdown]
# ### 소명대상_구분 별 이상거래 비율(Target Encoding) -> 가장 기본적인 방법(mean)

# %%
temp = df_temp.groupby('소명대상_구분')['label_소명여부'].mean()

# %%
temp_list = []

for i in tqdm(range(len(df_temp))):
    temp_list.append(temp[df_temp['소명대상_구분'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['소명대상_구분(mean)'] = temp_list

# %% [markdown]
# ### 가맹점 사무소 주소일치여부(시도)

# %%
temp_list = []
for i in tqdm(range(len(df_temp))) :
    if df_temp['br_address1'][i] != df_temp['address1'][i] :
        temp_list.append(1)
    else :
        temp_list.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['시도일치여부'] = temp_list

# %% [markdown]
# ### 1000원 단위 결제 여부

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_temp['금액'][i] < 100000000 and df_temp['금액'][i] % 1000 == 0 :
        temp_list.append(1)
    else :
        temp_list.append(0)

# %%
df_raw['1000단위여부'] = temp_list

# %% [markdown]
# ### 10000원 단위로 결제한 경우

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_temp['금액'][i] < 100000000 and df_temp['금액'][i] % 10000 == 0 :
        temp_list.append(1)
    else :
        temp_list.append(0)

# %%
df_raw['10000단위여부'] = temp_list

# %% [markdown]
# ### 50000원 단위로 결제한 경우

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_temp['금액'][i] < 100000000 and df_temp['금액'][i] % 50000 == 0 :
        temp_list.append(1)
    else :
        temp_list.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['50000단위여부'] = temp_list

# %% [markdown]
# ### 거리별 binning (이상거래 비율) (Target Encoding) -> 가장 기본적인 방법(mean)

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['distance'][i] <= 0.005 :
        temp_list.append('0 ~ 0.5km')
    elif df_raw['distance'][i] <= 0.01 :
        temp_list.append('0.5 ~ 1km')
    elif df_raw['distance'][i] <= 0.02 :
        temp_list.append('1 ~ 2km')
    elif df_raw['distance'][i] <= 0.05 :
        temp_list.append('2 ~ 5km')
    elif df_raw['distance'][i] <= 0.1 :
        temp_list.append('5 ~ 10km')
    elif df_raw['distance'][i] <= 0.2 :
        temp_list.append('10 ~ 20km')
    elif df_raw['distance'][i] <= 0.5 :
        temp_list.append('20 ~ 50km')
    else :
        temp_list.append('50km이상')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['distance_binning'] = temp_list

# %%
temp = df_raw.groupby('distance_binning')['label_소명여부'].mean()

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    temp_list.append(temp[df_raw['distance_binning'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['distance_binning(mean)'] = temp_list

# %%
df_raw.drop(['distance_binning'], axis='columns', inplace=True)

# %% [markdown]
# ### 금액별 binning (이상거래 비율) (Target Encoding) -> 가장 기본적인 방법(mean)

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['금액'][i] <= 10000 :
        temp_list.append('0 ~ 1만원')
    elif df_raw['금액'][i] <= 20000 :
        temp_list.append('1 ~ 2만원')
    elif df_raw['금액'][i] <= 50000 :
        temp_list.append('2 ~ 5만원')
    elif df_raw['금액'][i] <= 100000 :
        temp_list.append('5 ~ 10만원')
    elif df_raw['금액'][i] <= 500000 :
        temp_list.append('10 ~ 50만원')
    else :
        temp_list.append('50만원이상')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['금액_binning'] = temp_list

# %%
temp = df_raw.groupby('금액_binning')['label_소명여부'].mean()

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    temp_list.append(temp[df_raw['금액_binning'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['금액_binning(mean)'] = temp_list

# %%
df_raw.drop(['금액_binning'], axis='columns', inplace=True)

# %% [markdown]
# ### 개인 id별 평균 결제 금액 생성

# %%
temp = df_temp.groupby('개인id')['금액'].mean()

# %%
temp_list = []

for i in tqdm(range(len(df_temp))):
    temp_list.append(temp[df_temp['개인id'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['id_평균금액'] = temp_list

# %% [markdown]
# ### id별 평균금액 초과 여부

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['금액'][i] > df_raw['id_평균금액'][i] :
        temp_list.append(1)
    else :
        temp_list.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['id_평균금액_초과여부'] = temp_list

# %% [markdown]
# ### id별 평균 결제 거리

# %%
temp = df_temp.groupby('개인id')['distance'].mean()

# %%
temp_list = []

for i in tqdm(range(len(df_temp))) :
    temp_list.append(temp[df_temp['개인id'][i]])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['id_평균거리'] = temp_list

# %% [markdown]
# ### id별 평균거리 초과 여부

# %%
temp_list = []
for i in tqdm(range(len(df_raw))) :
    if df_raw['distance'][i] > df_raw['id_평균거리'][i] :
        temp_list.append(1)
    else :
        temp_list.append(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1518432.0), HTML(value='')))

# %%
df_raw['id_평균거리_초과여부'] = temp_list

# %%
df_raw.to_csv('파생변수생성데이터.csv.gz', encoding='euc-kr', index=False)

# %% [markdown]
# ## 분석 시작 부분

# %%
import copy

# %%
# del [[df_analyze]]

# %%
# deep copy 적용해야 원본 영향 X
df_analyze = copy.deepcopy(df_raw)

# %% [markdown]
# ### light_gbm 모델 사용시 한글 변수명이 존재하면 안되기 때문에 이름 변경

# %%
df_analyze.rename(columns={"label_소명여부" : "target"}, inplace = True)
df_analyze.rename(columns={"사무소코드" : "office_code"}, inplace = True)
df_analyze.rename(columns={"사용일" : "used_day1"}, inplace = True)
df_analyze.rename(columns={"시간" : "used_time"}, inplace = True)
df_analyze.rename(columns={"업종코드" : "industry_code"}, inplace = True)
df_analyze.rename(columns={"금액" : "cost"}, inplace = True)
df_analyze.rename(columns={"사용_시" : "used_hour"}, inplace = True)
df_analyze.rename(columns={"사용_분" : "used_minute"}, inplace = True)
df_analyze.rename(columns={"사용_초" : "used_second"}, inplace = True)
df_analyze.rename(columns={"사용_년" : "used_year"}, inplace = True)
df_analyze.rename(columns={"사용_월" : "used_month"}, inplace = True)
df_analyze.rename(columns={"사용_일" : "used_day"}, inplace = True)
df_analyze.rename(columns={"가중치" : "weight"}, inplace = True)
df_analyze.rename(columns={"사용요일_금" : "used_friday"}, inplace = True)
df_analyze.rename(columns={"사용요일_목" : "used_thursday"}, inplace = True)
df_analyze.rename(columns={"사용요일_수" : "used_wednesday"}, inplace = True)
df_analyze.rename(columns={"사용요일_월" : "used_monday"}, inplace = True)
df_analyze.rename(columns={"사용요일_일" : "used_sunday"}, inplace = True)
df_analyze.rename(columns={"사용요일_토" : "used_saturday"}, inplace = True)
df_analyze.rename(columns={"사용요일_화" : "used_tuesday"}, inplace = True)
df_analyze.rename(columns={"50만원이상" : "more_50"}, inplace = True)
df_analyze.rename(columns={"10만원이상" : "more_10"}, inplace = True)
df_analyze.rename(columns={"연휴여부" : "holiday_check"}, inplace = True)
df_analyze.rename(columns={"연휴전후여부" : "holiday_check2"}, inplace = True)
df_analyze.rename(columns={"소명대상_구분" : "mornitoring_check"}, inplace = True)
df_analyze.rename(columns={"22시이후" : "later_22h"}, inplace = True)
df_analyze.rename(columns={"주말여부" : "weekend_check"}, inplace = True)
df_analyze.rename(columns={"업종명(mean)" : "industry_name(mean)"}, inplace = True)
df_analyze.rename(columns={"세부업종명(mean)" : "detailed_industry_name(mean)"}, inplace = True)
df_analyze.rename(columns={"소명대상_구분(mean)" : "mornitoring_check(mean)"}, inplace = True)
df_analyze.rename(columns={"시도일치여부" : "address1_check"}, inplace = True)
df_analyze.rename(columns={"1000단위여부" : "1000_check"}, inplace = True)
df_analyze.rename(columns={"10000단위여부" : "10000_check"}, inplace = True)
df_analyze.rename(columns={"50000단위여부" : "50000_check"}, inplace = True)
df_analyze.rename(columns={"5km이상" : "more_5km"}, inplace = True)
df_analyze.rename(columns={"10km이상" : "more_10km"}, inplace = True)
df_analyze.rename(columns={"금액_binning(mean)" : "cost_binning(mean)"}, inplace = True)
df_analyze.rename(columns={"id_평균금액" : "id_avg_cost"}, inplace = True)
df_analyze.rename(columns={"id_평균금액_초과여부" : "id_avg_cost_check"}, inplace = True)
df_analyze.rename(columns={"id_평균거리" : "id_avg_distance"}, inplace = True)
df_analyze.rename(columns={"id_평균거리_초과여부" : "id_avg_distance_check"}, inplace = True)

# %%
df_analyze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1518432 entries, 0 to 1518431
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   target                        1518432 non-null  int64
#  1   office_code                   1518432 non-null  int64
#  2   used_day1                     1518432 non-null  int64
#  3   used_time                     1518432 non-null  int64
#  4   industry_code                 1518432 non-null  int64
#  5   cost                          1518432 non-null  int64
#  6   br_x                          1518432 non-null  float64
#  7   br_y                          1518432 non-null  float64
#  8   x                             1518432 non-null  float64
#  9   y                             1518432 non-null  float64
#  10  distance                      1518432 non-null  float64
#  11  used_hour                     1518432 non-null  int64
#  12  used_minute                   1518432 non-null  int64
#  13  used_second                   1518432 non-null  int64
#  14  used_year                     1518432 non-null  int64
#  15  used_month                    1518432 non-null  int64
#  16  used_day                      1518432 non-null  int64
#  17  used_friday                   1518432 non-null  int64
#  18  used_thursday                 1518432 non-null  int64
#  19  used_wednesday                1518432 non-null  int64
#  20  used_monday                   1518432 non-null  int64
#  21  used_sunday                   1518432 non-null  int64
#  22  used_saturday                 1518432 non-null  int64
#  23  used_tuesday                  1518432 non-null  int64
#  24  weight                        1518432 non-null  int64
#  25  more_50                       1518432 non-null  int32
#  26  more_10                       1518432 non-null  int32
#  27  holiday_check                 1518432 non-null  int64
#  28  holiday_check2                1518432 non-null  int64
#  29  mornitoring_check             1518432 non-null  int64
#  30  industry_name(mean)           1518432 non-null  float64
#  31  later_22h                     1518432 non-null  int64
#  32  weekend_check                 1518432 non-null  int64
#  33  detailed_industry_name(mean)  1518432 non-null  float64
#  34  mornitoring_check(mean)       1518432 non-null  float64
#  35  address1_check                1518432 non-null  int64
#  36  1000_check                    1518432 non-null  int64
#  37  10000_check                   1518432 non-null  int64
#  38  50000_check                   1518432 non-null  int64
#  39  distance_binning(mean)        1518432 non-null  float64
#  40  cost_binning(mean)            1518432 non-null  float64
#  41  id_avg_cost                   1518432 non-null  float64
#  42  id_avg_cost_more              1518432 non-null  int64
#  43  id_avg_distance               1518432 non-null  float64
#  44  id_avg_distance_more          1518432 non-null  int64
# dtypes: float64(12), int32(2), int64(31)
# memory usage: 509.7 MB

# %% [markdown]
# ### 목표변수(df_analyze_y) 설명변수(df_analyze_x) 지정

# %%
df_analyze_y = df_analyze['target']
df_analyze_x = df_analyze.drop('target', axis=1, inplace=False)

# %% [markdown]
# ### Overfitting을 방지하기 위한 train Set, test Set 7:3 분리 (Vallid Set 포함시 소명거래 비율이 너무 적어짐)
# ### random_state 옵션 적용시 항상 같은 결과를 낼 수 있음

# %%
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_analyze_x, df_analyze_y, test_size = 0.3)

# %% [markdown]
# ## SMOTE + ENN (OverSampling 기법) 적용
#
# ### 소명거래 비율이 현저하게 낮기 때문에(약 12,000개) undersampling 적용시 너무 적은 데이터로 학습
# ### 따라서 소명거래 데이터를 Oversampling 하는 기법 사용 -> 오히려 지표들이 상승하는 것을 확인

# %%
from imblearn.over_sampling import SMOTE
from imblearn.combine import *
# smote = SMOTE(random_state=0)
df_train_x_over, df_train_y_over = SMOTEENN(random_state=0).fit_sample(df_train_x, df_train_y)

# %% [markdown]
# ### SMOTE + ENN 샘플링 미적용 + LGBM option중 is_unbalane 적용
#
# ### Accuracy : 99.3% / Precision : 54.12% / Recall : 67.80% / F1-score : 60.19%
#
#
# LGBMClassifier 옵션 설명
# n_estimators : 트리 생성 반복 횟수
# is_unbalance : train Set과 test Set의 balance가 맞는지 (Oversampling 작업을 통해 맞춰놨음)
# min_data_in_leaf : 하나의 leaf에 최소 들어갈 수 있는 수
# num_leaves : 최대 leaves 수 설정
# learning_rate : learning rate 설정(중요) -> n_estimators 값에 따라 유동적으로 변경시켜주는 것이 좋음
# min_child_samples : child_samples의 최소 값

# %%
lgb = LGBMClassifier(n_estimators = 4000, is_unbalance = True, min_data_in_leaf=15, num_leaves=100, learning_rate=0.088, min_child_samples=30)
evals = [(df_test_x, df_test_y)]
lgb.fit(df_train_x, df_train_y, early_stopping_rounds = 2000, eval_metric = "AUC", eval_set = evals, verbose = True)
# Out:
# id_0's auc: 0.987519	valid_0's binary_logloss: 0.0334022
# [2938]	valid_0's auc: 0.987519	valid_0's binary_logloss: 0.0334086
# [2939]	valid_0's auc: 0.987524	valid_0's binary_logloss: 0.0334177
# [2940]	valid_0's auc: 0.987517	valid_0's binary_logloss: 0.0334268
# [2941]	valid_0's auc: 0.987521	valid_0's binary_logloss: 0.0334241
# [2942]	valid_0's auc: 0.987522	valid_0's binary_logloss: 0.0334282
# [2943]	valid_0's auc: 0.987523	valid_0's binary_logloss: 0.0334325
# [2944]	valid_0's auc: 0.987529	valid_0's binary_logloss: 0.0334404
# [2945]	valid_0's auc: 0.987535	valid_0's binary_logloss: 0.0334439
# [2946]	valid_0's auc: 0.987536	valid_0's binary_logloss: 0.0334478
# [2947]	valid_0's auc: 0.987537	valid_0's binary_logloss: 0.0334502
# [2948]	valid_0's auc: 0.987539	valid_0's binary_logloss: 0.0334542
# [2949]	valid_0's auc: 0.987537	valid_0's binary_logloss: 0.0334613
# [2950]	valid_0's auc: 0.987537	valid_0's binary_logloss: 0.0334617
# [2951]	valid_0's auc: 0.987536	valid_0's binary_logloss: 0.0334691
# [2952]	valid_0's auc: 0.987537	valid_0's binary_logloss: 0.0334718
# [2953]	valid_0's auc: 0.987538	valid_0's binary_logloss: 0.0334794
# [2954]	valid_0's auc: 0.987542	valid_0's binary_logloss: 0.0334874
# [2955]	valid_0's auc: 0.987541	valid_0's binary_logloss: 0.0334924
# [2956]	valid_0's auc: 0.987543	valid_0's binary_logloss: 0.0334998
# [2957]	valid_0's auc: 0.987544	valid_0's binary_logloss: 0.0335031
# [2958]	valid_0's auc: 0.987544	valid_0's binary_logloss: 0.0335072
# [2959]	valid_0's auc: 0.987541	valid_0's binary_logloss: 0.0335133
# [2960]	valid_0's auc: 0.987535	valid_0's binary_logloss: 0.0335206
# [2961]	valid_0's auc: 0.987534	valid_0's binary_logloss: 0.0335239
# [2962]	valid_0's auc: 0.987532	valid_0's binary_logloss: 0.0335319
# [2963]	valid_0's auc: 0.987533	valid_0's binary_logloss: 0.0335379
# [2964]	valid_0's auc: 0.987544	valid_0's binary_logloss: 0.0335431
# [2965]	valid_0's auc: 0.987544	valid_0's binary_logloss: 0.0335496
# [2966]	valid_0's auc: 0.987546	valid_0's binary_logloss: 0.0335503
# [2967]	valid_0's auc: 0.987602	valid_0's binary_logloss: 0.0335584
# [2968]	valid_0's auc: 0.987602	valid_0's binary_logloss: 0.0335653
# [2969]	valid_0's auc: 0.987597	valid_0's binary_logloss: 0.0335683
# [2970]	valid_0's auc: 0.987599	valid_0's binary_logloss: 0.0335749
# [2971]	valid_0's auc: 0.987603	valid_0's binary_logloss: 0.0335795
# [2972]	valid_0's auc: 0.987602	valid_0's binary_logloss: 0.0335843
# [2973]	valid_0's auc: 0.987603	valid_0's binary_logloss: 0.0335878
# [2974]	valid_0's auc: 0.987606	valid_0's binary_logloss: 0.0335905
# [2975]	valid_0's auc: 0.987607	valid_0's binary_logloss: 0.0335926
# [2976]	valid_0's auc: 0.987612	valid_0's binary_logloss: 0.0335979
# [2977]	valid_0's auc: 0.987616	valid_0's binary_logloss: 0.0335993
# [2978]	valid_0's auc: 0.987615	valid_0's binary_logloss: 0.0336034
# [2979]	valid_0's auc: 0.987616	valid_0's binary_logloss: 0.0336072
# [2980]	valid_0's auc: 0.987614	valid_0's binary_logloss: 0.0336128
# [2981]	valid_0's auc: 0.987619	valid_0's binary_logloss: 0.0336153
# [2982]	valid_0's auc: 0.987623	valid_0's binary_logloss: 0.0336247
# [2983]	valid_0's auc: 0.987628	valid_0's binary_logloss: 0.0336293
# [2984]	valid_0's auc: 0.987627	valid_0's binary_logloss: 0.0336311
# [2985]	valid_0's auc: 0.987629	valid_0's binary_logloss: 0.0336359
# [2986]	valid_0's auc: 0.987629	valid_0's binary_logloss: 0.0336403
# [2987]	valid_0's auc: 0.987635	valid_0's binary_logloss: 0.0336389
# [2988]	valid_0's auc: 0.987627	valid_0's binary_logloss: 0.03365
# [2989]	valid_0's auc: 0.987633	valid_0's binary_logloss: 0.0336541
# [2990]	valid_0's auc: 0.987637	valid_0's binary_logloss: 0.0336576
# [2991]	valid_0's auc: 0.987637	valid_0's binary_logloss: 0.0336584
# [2992]	valid_0's auc: 0.987638	valid_0's binary_logloss: 0.0336624
# [2993]	valid_0's auc: 0.987638	valid_0's binary_logloss: 0.0336655
# [2994]	valid_0's auc: 0.987644	valid_0's binary_logloss: 0.0336714
# [2995]	valid_0's auc: 0.987643	valid_0's binary_logloss: 0.0336787
# [2996]	valid_0's auc: 0.987644	valid_0's binary_logloss: 0.0336803
# [2997]	valid_0's auc: 0.987654	valid_0's binary_logloss: 0.0336871
# [2998]	valid_0's auc: 0.987659	valid_0's binary_logloss: 0.0336895
# [2999]	valid_0's auc: 0.987662	valid_0's binary_logloss: 0.0336987
# [3000]	valid_0's auc: 0.987664	valid_0's binary_logloss: 0.0336979
# [3001]	valid_0's auc: 0.987662	valid_0's binary_logloss: 0.0336971
# [3002]	valid_0's auc: 0.987661	valid_0's binary_logloss: 0.0337039
# [3003]	valid_0's auc: 0.987663	valid_0's binary_logloss: 0.0337068
# [3004]	valid_0's auc: 0.987663	valid_0's binary_logloss: 0.0337131
# [3005]	valid_0's auc: 0.987666	valid_0's binary_logloss: 0.0337136
# [3006]	valid_0's auc: 0.987664	valid_0's binary_logloss: 0.0337242
# [3007]	valid_0's auc: 0.987663	valid_0's binary_logloss: 0.0337302
# [3008]	valid_0's auc: 0.987664	valid_0's binary_logloss: 0.0337356
# [3009]	valid_0's auc: 0.987665	valid_0's binary_logloss: 0.0337366
# [3010]	valid_0's auc: 0.987664	valid_0's binary_logloss: 0.0337376
# [3011]	valid_0's auc: 0.987662	valid_0's binary_logloss: 0.033744
# [3012]	valid_0's auc: 0.987683	valid_0's binary_logloss: 0.0337515
# [3013]	valid_0's auc: 0.987683	valid_0's binary_logloss: 0.0337557
# [3014]	valid_0's auc: 0.987683	valid_0's binary_logloss: 0.0337606
# [3015]	valid_0's auc: 0.987684	valid_0's binary_logloss: 0.0337633
# [3016]	valid_0's auc: 0.987684	valid_0's binary_logloss: 0.0337661
# [3017]	valid_0's auc: 0.987694	valid_0's binary_logloss: 0.0337745
# [3018]	valid_0's auc: 0.987693	valid_0's binary_logloss: 0.0337813
# [3019]	valid_0's auc: 0.987695	valid_0's binary_logloss: 0.0337898
# [3020]	valid_0's auc: 0.987695	valid_0's binary_logloss: 0.0337923
# [3021]	valid_0's auc: 0.987692	valid_0's binary_logloss: 0.0338048
# [3022]	valid_0's auc: 0.987694	valid_0's binary_logloss: 0.0338076
# [3023]	valid_0's auc: 0.987694	valid_0's binary_logloss: 0.0338117
# [3024]	valid_0's auc: 0.987691	valid_0's binary_logloss: 0.0338136
# [3025]	valid_0's auc: 0.987694	valid_0's binary_logloss: 0.033823
# [3026]	valid_0's auc: 0.987692	valid_0's binary_logloss: 0.0338272
# [3027]	valid_0's auc: 0.987693	valid_0's binary_logloss: 0.0338307
# [3028]	valid_0's auc: 0.987692	valid_0's binary_logloss: 0.0338338
# [3029]	valid_0's auc: 0.987692	valid_0's binary_logloss: 0.033838
# [3030]	valid_0's auc: 0.987702	valid_0's binary_logloss: 0.033844
# [3031]	valid_0's auc: 0.987704	valid_0's binary_logloss: 0.0338504
# [3032]	valid_0's auc: 0.987706	valid_0's binary_logloss: 0.0338562
# [3033]	valid_0's auc: 0.987705	valid_0's binary_logloss: 0.033862
# [3034]	valid_0's auc: 0.987703	valid_0's binary_logloss: 0.033868
# [3035]	valid_0's auc: 0.987701	valid_0's binary_logloss: 0.0338717
# [3036]	valid_0's auc: 0.9877	valid_0's binary_logloss: 0.0338718
# [3037]	valid_0's auc: 0.987711	valid_0's binary_logloss: 0.033882
# [3038]	valid_0's auc: 0.987709	valid_0's binary_logloss: 0.033887
# [3039]	valid_0's auc: 0.987706	valid_0's binary_logloss: 0.033891
# [3040]	valid_0's auc: 0.987723	valid_0's binary_logloss: 0.0338988
# [3041]	valid_0's auc: 0.987724	valid_0's binary_logloss: 0.0339028
# [3042]	valid_0's auc: 0.987732	valid_0's binary_logloss: 0.0339075
# [3043]	valid_0's auc: 0.987736	valid_0's binary_logloss: 0.0339112
# [3044]	valid_0's auc: 0.987736	valid_0's binary_logloss: 0.033913
# [3045]	valid_0's auc: 0.987733	valid_0's binary_logloss: 0.0339202
# [3046]	valid_0's auc: 0.987734	valid_0's binary_logloss: 0.0339238
# [3047]	valid_0's auc: 0.987734	valid_0's binary_logloss: 0.0339326
# [3048]	valid_0's auc: 0.987732	valid_0's binary_logloss: 0.0339417
# [3049]	valid_0's auc: 0.987734	valid_0's binary_logloss: 0.0339468
# [3050]	valid_0's auc: 0.987732	valid_0's binary_logloss: 0.0339494
# [3051]	valid_0's auc: 0.987733	valid_0's binary_logloss: 0.0339506
# [3052]	valid_0's auc: 0.987735	valid_0's binary_logloss: 0.0339521
# [3053]	valid_0's auc: 0.987736	valid_0's binary_logloss: 0.0339555
# [3054]	valid_0's auc: 0.987735	valid_0's binary_logloss: 0.0339604
# [3055]	valid_0's auc: 0.987733	valid_0's binary_logloss: 0.0339665
# [3056]	valid_0's auc: 0.987735	valid_0's binary_logloss: 0.033975
# [3057]	valid_0's auc: 0.987736	valid_0's binary_logloss: 0.0339833
# [3058]	valid_0's auc: 0.987735	valid_0's binary_logloss: 0.0339878
# [3059]	valid_0's auc: 0.987731	valid_0's binary_logloss: 0.03399
# [3060]	valid_0's auc: 0.987738	valid_0's binary_logloss: 0.0339899
# [3061]	valid_0's auc: 0.98774	valid_0's binary_logloss: 0.0339951
# [3062]	valid_0's auc: 0.987739	valid_0's binary_logloss: 0.0339989
# [3063]	valid_0's auc: 0.987741	valid_0's binary_logloss: 0.034002
# [3064]	valid_0's auc: 0.987739	valid_0's binary_logloss: 0.0340063
# [3065]	valid_0's auc: 0.987739	valid_0's binary_logloss: 0.0340091
# [3066]	valid_0's auc: 0.987741	valid_0's binary_logloss: 0.0340119
# [3067]	valid_0's auc: 0.987756	valid_0's binary_logloss: 0.0340177
# [3068]	valid_0's auc: 0.987759	valid_0's binary_logloss: 0.0340217
# [3069]	valid_0's auc: 0.987758	valid_0's binary_logloss: 0.0340286
# [3070]	valid_0's auc: 0.98776	valid_0's binary_logloss: 0.0340361
# [3071]	valid_0's auc: 0.987765	valid_0's binary_logloss: 0.0340423
# [3072]	valid_0's auc: 0.987767	valid_0's binary_logloss: 0.0340445
# [3073]	valid_0's auc: 0.987767	valid_0's binary_logloss: 0.0340526
# [3074]	valid_0's auc: 0.987768	valid_0's binary_logloss: 0.0340557
# [3075]	valid_0's auc: 0.98777	valid_0's binary_logloss: 0.0340578
# [3076]	valid_0's auc: 0.987771	valid_0's binary_logloss: 0.0340598
# [3077]	valid_0's auc: 0.987773	valid_0's binary_logloss: 0.0340659
# [3078]	valid_0's auc: 0.987771	valid_0's binary_logloss: 0.03407
# [3079]	valid_0's auc: 0.987772	valid_0's binary_logloss: 0.0340685
# [3080]	valid_0's auc: 0.987782	valid_0's binary_logloss: 0.034077
# [3081]	valid_0's auc: 0.987788	valid_0's binary_logloss: 0.0340789
# [3082]	valid_0's auc: 0.987787	valid_0's binary_logloss: 0.0340808
# [3083]	valid_0's auc: 0.987781	valid_0's binary_logloss: 0.0340897
# [3084]	valid_0's auc: 0.987783	valid_0's binary_logloss: 0.0340959
# [3085]	valid_0's auc: 0.987784	valid_0's binary_logloss: 0.0340981
# [3086]	valid_0's auc: 0.987784	valid_0's binary_logloss: 0.0340998
# [3087]	valid_0's auc: 0.987783	valid_0's binary_logloss: 0.0341063
# [3088]	valid_0's auc: 0.987785	valid_0's binary_logloss: 0.0341084
# [3089]	valid_0's auc: 0.987782	valid_0's binary_logloss: 0.034113
# [3090]	valid_0's auc: 0.987781	valid_0's binary_logloss: 0.0341169
# [3091]	valid_0's auc: 0.987783	valid_0's binary_logloss: 0.0341226
# [3092]	valid_0's auc: 0.987783	valid_0's binary_logloss: 0.0341275
# [3093]	valid_0's auc: 0.987784	valid_0's binary_logloss: 0.0341313
# [3094]	valid_0's auc: 0.987788	valid_0's binary_logloss: 0.0341378
# [3095]	valid_0's auc: 0.987787	valid_0's binary_logloss: 0.0341385
# [3096]	valid_0's auc: 0.987782	valid_0's binary_logloss: 0.034146
# [3097]	valid_0's auc: 0.98778	valid_0's binary_logloss: 0.034147
# [3098]	valid_0's auc: 0.98778	valid_0's binary_logloss: 0.0341503
# [3099]	valid_0's auc: 0.987778	valid_0's binary_logloss: 0.0341591
# [3100]	valid_0's auc: 0.987778	valid_0's binary_logloss: 0.0341609
# [3101]	valid_0's auc: 0.987779	valid_0's binary_logloss: 0.0341676
# [3102]	valid_0's auc: 0.987775	valid_0's binary_logloss: 0.034173
# [3103]	valid_0's auc: 0.987773	valid_0's binary_logloss: 0.0341773
# [3104]	valid_0's auc: 0.987774	valid_0's binary_logloss: 0.0341832
# [3105]	valid_0's auc: 0.987774	valid_0's binary_logloss: 0.0341858
# [3106]	valid_0's auc: 0.987777	valid_0's binary_logloss: 0.0341934
# [3107]	valid_0's auc: 0.987781	valid_0's binary_logloss: 0.0341933
# [3108]	valid_0's auc: 0.987781	valid_0's binary_logloss: 0.0341943
# [3109]	valid_0's auc: 0.98778	valid_0's binary_logloss: 0.0342023
# [3110]	valid_0's auc: 0.987781	valid_0's binary_logloss: 0.0342076
# [3111]	valid_0's auc: 0.987781	valid_0's binary_logloss: 0.0342091
# [3112]	valid_0's auc: 0.987782	valid_0's binary_logloss: 0.0342119
# [3113]	valid_0's auc: 0.987784	valid_0's binary_logloss: 0.0342178
# [3114]	valid_0's auc: 0.987785	valid_0's binary_logloss: 0.0342219
# [3115]	valid_0's auc: 0.987784	valid_0's binary_logloss: 0.0342254
# [3116]	valid_0's auc: 0.987836	valid_0's binary_logloss: 0.0342317
# [3117]	valid_0's auc: 0.98784	valid_0's binary_logloss: 0.0342358
# [3118]	valid_0's auc: 0.987841	valid_0's binary_logloss: 0.0342379
# [3119]	valid_0's auc: 0.987843	valid_0's binary_logloss: 0.0342424
# [3120]	valid_0's auc: 0.987843	valid_0's binary_logloss: 0.0342526
# [3121]	valid_0's auc: 0.98784	valid_0's binary_logloss: 0.0342562
# [3122]	valid_0's auc: 0.987843	valid_0's binary_logloss: 0.0342572
# [3123]	valid_0's auc: 0.987856	valid_0's binary_logloss: 0.0342614
# [3124]	valid_0's auc: 0.987856	valid_0's binary_logloss: 0.0342653
# [3125]	valid_0's auc: 0.987855	valid_0's binary_logloss: 0.0342688
# [3126]	valid_0's auc: 0.987857	valid_0's binary_logloss: 0.0342766
# [3127]	valid_0's auc: 0.987859	valid_0's binary_logloss: 0.0342782
# [3128]	valid_0's auc: 0.987862	valid_0's binary_logloss: 0.0342806
# [3129]	valid_0's auc: 0.987861	valid_0's binary_logloss: 0.034285
# [3130]	valid_0's auc: 0.987865	valid_0's binary_logloss: 0.03429
# [3131]	valid_0's auc: 0.987865	valid_0's binary_logloss: 0.0342921
# [3132]	valid_0's auc: 0.987864	valid_0's binary_logloss: 0.0342993
# [3133]	valid_0's auc: 0.987866	valid_0's binary_logloss: 0.0343058
# [3134]	valid_0's auc: 0.987866	valid_0's binary_logloss: 0.034308
# [3135]	valid_0's auc: 0.987865	valid_0's binary_logloss: 0.034309
# [3136]	valid_0's auc: 0.987864	valid_0's binary_logloss: 0.0343105
# [3137]	valid_0's auc: 0.987866	valid_0's binary_logloss: 0.0343169
# [3138]	valid_0's auc: 0.98787	valid_0's binary_logloss: 0.0343236
# [3139]	valid_0's auc: 0.987888	valid_0's binary_logloss: 0.0343316
# [3140]	valid_0's auc: 0.987891	valid_0's binary_logloss: 0.0343355
# [3141]	valid_0's auc: 0.987894	valid_0's binary_logloss: 0.0343384
# [3142]	valid_0's auc: 0.987894	valid_0's binary_logloss: 0.0343436
# [3143]	valid_0's auc: 0.987892	valid_0's binary_logloss: 0.0343472
# [3144]	valid_0's auc: 0.987896	valid_0's binary_logloss: 0.0343496
# [3145]	valid_0's auc: 0.987953	valid_0's binary_logloss: 0.0343563
# [3146]	valid_0's auc: 0.987962	valid_0's binary_logloss: 0.0343594
# [3147]	valid_0's auc: 0.987959	valid_0's binary_logloss: 0.0343666
# [3148]	valid_0's auc: 0.987959	valid_0's binary_logloss: 0.0343706
# [3149]	valid_0's auc: 0.987957	valid_0's binary_logloss: 0.0343718
# [3150]	valid_0's auc: 0.987957	valid_0's binary_logloss: 0.0343747
# [3151]	valid_0's auc: 0.987956	valid_0's binary_logloss: 0.0343778
# [3152]	valid_0's auc: 0.987961	valid_0's binary_logloss: 0.0343821
# [3153]	valid_0's auc: 0.98796	valid_0's binary_logloss: 0.0343875
# [3154]	valid_0's auc: 0.98796	valid_0's binary_logloss: 0.0343898
# [3155]	valid_0's auc: 0.98796	valid_0's binary_logloss: 0.0343919
# [3156]	valid_0's auc: 0.98796	valid_0's binary_logloss: 0.0343974
# [3157]	valid_0's auc: 0.987959	valid_0's binary_logloss: 0.0343982
# [3158]	valid_0's auc: 0.987961	valid_0's binary_logloss: 0.0344002
# [3159]	valid_0's auc: 0.987963	valid_0's binary_logloss: 0.0344059
# [3160]	valid_0's auc: 0.987965	valid_0's binary_logloss: 0.0344104
# [3161]	valid_0's auc: 0.987963	valid_0's binary_logloss: 0.0344185
# [3162]	valid_0's auc: 0.98796	valid_0's binary_logloss: 0.034422
# [3163]	valid_0's auc: 0.987962	valid_0's binary_logloss: 0.0344241
# [3164]	valid_0's auc: 0.987959	valid_0's binary_logloss: 0.0344338
# [3165]	valid_0's auc: 0.987958	valid_0's binary_logloss: 0.034435
# [3166]	valid_0's auc: 0.987964	valid_0's binary_logloss: 0.0344385
# [3167]	valid_0's auc: 0.987958	valid_0's binary_logloss: 0.0344439
# [3168]	valid_0's auc: 0.987959	valid_0's binary_logloss: 0.0344473
# [3169]	valid_0's auc: 0.98796	valid_0's binary_logloss: 0.0344579
# [3170]	valid_0's auc: 0.987958	valid_0's binary_logloss: 0.0344638
# [3171]	valid_0's auc: 0.987958	valid_0's binary_logloss: 0.0344708
# [3172]	valid_0's auc: 0.987957	valid_0's binary_logloss: 0.0344744
# [3173]	valid_0's auc: 0.987962	valid_0's binary_logloss: 0.0344796
# [3174]	valid_0's auc: 0.987959	valid_0's binary_logloss: 0.0344822
# [3175]	valid_0's auc: 0.987962	valid_0's binary_logloss: 0.034487
# [3176]	valid_0's auc: 0.987962	valid_0's binary_logloss: 0.0344921
# [3177]	valid_0's auc: 0.987964	valid_0's binary_logloss: 0.0344917
# [3178]	valid_0's auc: 0.987963	valid_0's binary_logloss: 0.0344936
# [3179]	valid_0's auc: 0.987963	valid_0's binary_logloss: 0.0344992
# [3180]	valid_0's auc: 0.987962	valid_0's binary_logloss: 0.0345054
# [3181]	valid_0's auc: 0.987971	valid_0's binary_logloss: 0.0345058
# [3182]	valid_0's auc: 0.987972	valid_0's binary_logloss: 0.0345089
# [3183]	valid_0's auc: 0.987974	valid_0's binary_logloss: 0.034518
# [3184]	valid_0's auc: 0.987976	valid_0's binary_logloss: 0.0345189
# [3185]	valid_0's auc: 0.987977	valid_0's binary_logloss: 0.0345216
# [3186]	valid_0's auc: 0.987975	valid_0's binary_logloss: 0.0345285
# [3187]	valid_0's auc: 0.987975	valid_0's binary_logloss: 0.034534
# [3188]	valid_0's auc: 0.987977	valid_0's binary_logloss: 0.0345338
# [3189]	valid_0's auc: 0.987976	valid_0's binary_logloss: 0.0345365
# [3190]	valid_0's auc: 0.987977	valid_0's binary_logloss: 0.0345405
# [3191]	valid_0's auc: 0.987978	valid_0's binary_logloss: 0.0345468
# [3192]	valid_0's auc: 0.987976	valid_0's binary_logloss: 0.0345505
# [3193]	valid_0's auc: 0.987977	valid_0's binary_logloss: 0.0345543
# [3194]	valid_0's auc: 0.987979	valid_0's binary_logloss: 0.0345607
# [3195]	valid_0's auc: 0.987979	valid_0's binary_logloss: 0.0345637
# [3196]	valid_0's auc: 0.987981	valid_0's binary_logloss: 0.0345655
# [3197]	valid_0's auc: 0.987982	valid_0's binary_logloss: 0.0345702
# [3198]	valid_0's auc: 0.987982	valid_0's binary_logloss: 0.034573
# [3199]	valid_0's auc: 0.987982	valid_0's binary_logloss: 0.0345734
# [3200]	valid_0's auc: 0.987978	valid_0's binary_logloss: 0.0345781
# [3201]	valid_0's auc: 0.987975	valid_0's binary_logloss: 0.0345833
# [3202]	valid_0's auc: 0.987975	valid_0's binary_logloss: 0.034585
# [3203]	valid_0's auc: 0.987973	valid_0's binary_logloss: 0.0345906
# [3204]	valid_0's auc: 0.987976	valid_0's binary_logloss: 0.0345979
# [3205]	valid_0's auc: 0.987976	valid_0's binary_logloss: 0.0346047
# [3206]	valid_0's auc: 0.987976	valid_0's binary_logloss: 0.0346091
# [3207]	valid_0's auc: 0.98799	valid_0's binary_logloss: 0.0346136
# [3208]	valid_0's auc: 0.987986	valid_0's binary_logloss: 0.0346153
# [3209]	valid_0's auc: 0.987986	valid_0's binary_logloss: 0.0346241
# [3210]	valid_0's auc: 0.988018	valid_0's binary_logloss: 0.0346243
# [3211]	valid_0's auc: 0.988016	valid_0's binary_logloss: 0.0346253
# [3212]	valid_0's auc: 0.988016	valid_0's binary_logloss: 0.0346266
# [3213]	valid_0's auc: 0.988015	valid_0's binary_logloss: 0.0346297
# [3214]	valid_0's auc: 0.988011	valid_0's binary_logloss: 0.0346345
# [3215]	valid_0's auc: 0.98801	valid_0's binary_logloss: 0.0346371
# [3216]	valid_0's auc: 0.988007	valid_0's binary_logloss: 0.0346432
# [3217]	valid_0's auc: 0.988012	valid_0's binary_logloss: 0.0346408
# [3218]	valid_0's auc: 0.988013	valid_0's binary_logloss: 0.0346454
# [3219]	valid_0's auc: 0.988015	valid_0's binary_logloss: 0.0346463
# [3220]	valid_0's auc: 0.988015	valid_0's binary_logloss: 0.0346477
# [3221]	valid_0's auc: 0.988016	valid_0's binary_logloss: 0.0346506
# [3222]	valid_0's auc: 0.988019	valid_0's binary_logloss: 0.0346565
# [3223]	valid_0's auc: 0.988023	valid_0's binary_logloss: 0.0346602
# [3224]	valid_0's auc: 0.988025	valid_0's binary_logloss: 0.0346654
# [3225]	valid_0's auc: 0.988025	valid_0's binary_logloss: 0.034666
# [3226]	valid_0's auc: 0.988023	valid_0's binary_logloss: 0.0346707
# [3227]	valid_0's auc: 0.988024	valid_0's binary_logloss: 0.0346759
# [3228]	valid_0's auc: 0.988019	valid_0's binary_logloss: 0.0346831
# [3229]	valid_0's auc: 0.98802	valid_0's binary_logloss: 0.0346811
# [3230]	valid_0's auc: 0.988022	valid_0's binary_logloss: 0.0346885
# [3231]	valid_0's auc: 0.988024	valid_0's binary_logloss: 0.0346897
# [3232]	valid_0's auc: 0.988024	valid_0's binary_logloss: 0.0346924
# [3233]	valid_0's auc: 0.98802	valid_0's binary_logloss: 0.0346996
# [3234]	valid_0's auc: 0.988019	valid_0's binary_logloss: 0.034705
# Early stopping, best iteration is:
# [1234]	valid_0's auc: 0.975941	valid_0's binary_logloss: 0.0288437
# LGBMClassifier(is_unbalance=True, learning_rate=0.088, min_child_samples=30,
#                min_data_in_leaf=15, n_estimators=4000, num_leaves=100)

# %%
# 평가
y_pred = lgb.predict(df_test_x, num_iteration=lgb.best_iteration_)
# y_pred = lgb.predict(df_test_x, num_iteration=1306)
print("Accuracy: {0:.3f}\n".format(lgb.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.993
#
#               precision    recall  f1-score   support
#
#      class 0     0.9974    0.9954    0.9964    451928
#      class 1     0.5412    0.6780    0.6019      3602
#
#     accuracy                         0.9929    455530
#    macro avg     0.7693    0.8367    0.7992    455530
# weighted avg     0.9938    0.9929    0.9933    455530
#
# Confusion matrix:
# [[449858   2070]
#  [  1160   2442]]

# %% [markdown]
# ### SMOTE + ENN 샘플링 적용 + is_unbalane 적용
#
# ### Accuracy : 99.7% / Precision : 80.90% / Recall : 87.59% / F1-score : 84.11%

# %%
lgb = LGBMClassifier(n_estimators = 4000, is_unbalance = True, min_data_in_leaf=15, num_leaves=100, learning_rate=0.088, min_child_samples=30)
evals = [(df_test_x, df_test_y)]
lgb.fit(df_train_x_over, df_train_y_over, early_stopping_rounds = 2000, eval_metric = "AUC", eval_set = evals, verbose = True)
# Out:
# 8	valid_0's binary_logloss: 0.0120174
# [2737]	valid_0's auc: 0.998907	valid_0's binary_logloss: 0.0120212
# [2738]	valid_0's auc: 0.998908	valid_0's binary_logloss: 0.0120199
# [2739]	valid_0's auc: 0.998908	valid_0's binary_logloss: 0.0120203
# [2740]	valid_0's auc: 0.998908	valid_0's binary_logloss: 0.0120213
# [2741]	valid_0's auc: 0.998909	valid_0's binary_logloss: 0.0120219
# [2742]	valid_0's auc: 0.998908	valid_0's binary_logloss: 0.0120263
# [2743]	valid_0's auc: 0.998907	valid_0's binary_logloss: 0.0120298
# [2744]	valid_0's auc: 0.998908	valid_0's binary_logloss: 0.0120293
# [2745]	valid_0's auc: 0.998907	valid_0's binary_logloss: 0.0120323
# [2746]	valid_0's auc: 0.998908	valid_0's binary_logloss: 0.0120335
# [2747]	valid_0's auc: 0.998909	valid_0's binary_logloss: 0.0120343
# [2748]	valid_0's auc: 0.998909	valid_0's binary_logloss: 0.0120398
# [2749]	valid_0's auc: 0.998909	valid_0's binary_logloss: 0.0120406
# [2750]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.0120396
# [2751]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.012039
# [2752]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.0120423
# [2753]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.0120427
# [2754]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.0120462
# [2755]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.0120458
# [2756]	valid_0's auc: 0.99891	valid_0's binary_logloss: 0.0120509
# [2757]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120538
# [2758]	valid_0's auc: 0.998911	valid_0's binary_logloss: 0.0120555
# [2759]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120552
# [2760]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120592
# [2761]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120592
# [2762]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120611
# [2763]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120655
# [2764]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120672
# [2765]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120675
# [2766]	valid_0's auc: 0.998912	valid_0's binary_logloss: 0.0120696
# [2767]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0120753
# [2768]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.01208
# [2769]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0120896
# [2770]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0120896
# [2771]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0120925
# [2772]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0120988
# [2773]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0120994
# [2774]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121029
# [2775]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121071
# [2776]	valid_0's auc: 0.998914	valid_0's binary_logloss: 0.0121105
# [2777]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121098
# [2778]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121199
# [2779]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121201
# [2780]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.01212
# [2781]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121288
# [2782]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121291
# [2783]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121392
# [2784]	valid_0's auc: 0.998913	valid_0's binary_logloss: 0.0121393
# [2785]	valid_0's auc: 0.998914	valid_0's binary_logloss: 0.0121452
# [2786]	valid_0's auc: 0.998915	valid_0's binary_logloss: 0.0121436
# [2787]	valid_0's auc: 0.998915	valid_0's binary_logloss: 0.0121484
# [2788]	valid_0's auc: 0.998915	valid_0's binary_logloss: 0.0121504
# [2789]	valid_0's auc: 0.998914	valid_0's binary_logloss: 0.0121566
# [2790]	valid_0's auc: 0.998914	valid_0's binary_logloss: 0.0121612
# [2791]	valid_0's auc: 0.998914	valid_0's binary_logloss: 0.0121598
# [2792]	valid_0's auc: 0.998915	valid_0's binary_logloss: 0.0121595
# [2793]	valid_0's auc: 0.998915	valid_0's binary_logloss: 0.0121593
# [2794]	valid_0's auc: 0.998915	valid_0's binary_logloss: 0.0121616
# [2795]	valid_0's auc: 0.998916	valid_0's binary_logloss: 0.0121636
# [2796]	valid_0's auc: 0.998916	valid_0's binary_logloss: 0.0121693
# [2797]	valid_0's auc: 0.998917	valid_0's binary_logloss: 0.0121701
# [2798]	valid_0's auc: 0.998917	valid_0's binary_logloss: 0.0121717
# [2799]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0121719
# [2800]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.012174
# [2801]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0121742
# [2802]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0121745
# [2803]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.012177
# [2804]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0121781
# [2805]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0121809
# [2806]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0121805
# [2807]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0121856
# [2808]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0121898
# [2809]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0121901
# [2810]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0121919
# [2811]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012194
# [2812]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0121944
# [2813]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122013
# [2814]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122004
# [2815]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0121998
# [2816]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122044
# [2817]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122054
# [2818]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122071
# [2819]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122084
# [2820]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122132
# [2821]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122206
# [2822]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122199
# [2823]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122193
# [2824]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122279
# [2825]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122279
# [2826]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122291
# [2827]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122359
# [2828]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122367
# [2829]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122365
# [2830]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122348
# [2831]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122374
# [2832]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122392
# [2833]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122425
# [2834]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122432
# [2835]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122501
# [2836]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122625
# [2837]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122647
# [2838]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122659
# [2839]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122662
# [2840]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122652
# [2841]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122667
# [2842]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0122713
# [2843]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122744
# [2844]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122829
# [2845]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0122857
# [2846]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122868
# [2847]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122877
# [2848]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122896
# [2849]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122929
# [2850]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122915
# [2851]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012293
# [2852]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0122996
# [2853]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123032
# [2854]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123101
# [2855]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123128
# [2856]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123138
# [2857]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123222
# [2858]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012324
# [2859]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123277
# [2860]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123384
# [2861]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123394
# [2862]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.012342
# [2863]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123441
# [2864]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123445
# [2865]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123452
# [2866]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123469
# [2867]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123507
# [2868]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123506
# [2869]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123614
# [2870]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123611
# [2871]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123687
# [2872]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123719
# [2873]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123743
# [2874]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123742
# [2875]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.012375
# [2876]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123824
# [2877]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012382
# [2878]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123837
# [2879]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123851
# [2880]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123842
# [2881]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123891
# [2882]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0123971
# [2883]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012399
# [2884]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0123999
# [2885]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124017
# [2886]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124004
# [2887]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0124034
# [2888]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124081
# [2889]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124108
# [2890]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124239
# [2891]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124256
# [2892]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124265
# [2893]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124315
# [2894]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124328
# [2895]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124341
# [2896]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124412
# [2897]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124413
# [2898]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124408
# [2899]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124409
# [2900]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124413
# [2901]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124443
# [2902]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124491
# [2903]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124496
# [2904]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124554
# [2905]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124558
# [2906]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.012456
# [2907]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124602
# [2908]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124613
# [2909]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124626
# [2910]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0124672
# [2911]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124673
# [2912]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124704
# [2913]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124732
# [2914]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0124777
# [2915]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124827
# [2916]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012485
# [2917]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124905
# [2918]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124908
# [2919]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124915
# [2920]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0124938
# [2921]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0124946
# [2922]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0124945
# [2923]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0124962
# [2924]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125012
# [2925]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125033
# [2926]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125047
# [2927]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125065
# [2928]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0125053
# [2929]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.01251
# [2930]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0125107
# [2931]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0125147
# [2932]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0125224
# [2933]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125307
# [2934]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125336
# [2935]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125343
# [2936]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125395
# [2937]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125412
# [2938]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0125393
# [2939]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.012543
# [2940]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.012553
# [2941]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012555
# [2942]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125582
# [2943]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125637
# [2944]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125634
# [2945]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.012564
# [2946]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125652
# [2947]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.012577
# [2948]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125782
# [2949]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0125818
# [2950]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125803
# [2951]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0125843
# [2952]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.012585
# [2953]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0125935
# [2954]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0125963
# [2955]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0125947
# [2956]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0125948
# [2957]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.012594
# [2958]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.012598
# [2959]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126055
# [2960]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126089
# [2961]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126093
# [2962]	valid_0's auc: 0.998917	valid_0's binary_logloss: 0.0126118
# [2963]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126201
# [2964]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126182
# [2965]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126214
# [2966]	valid_0's auc: 0.998917	valid_0's binary_logloss: 0.0126219
# [2967]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126241
# [2968]	valid_0's auc: 0.998917	valid_0's binary_logloss: 0.0126261
# [2969]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126255
# [2970]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126265
# [2971]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.012626
# [2972]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126298
# [2973]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126333
# [2974]	valid_0's auc: 0.998918	valid_0's binary_logloss: 0.0126334
# [2975]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0126328
# [2976]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0126324
# [2977]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126377
# [2978]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126367
# [2979]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126364
# [2980]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126384
# [2981]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126438
# [2982]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126457
# [2983]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126474
# [2984]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126522
# [2985]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.012656
# [2986]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126632
# [2987]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126683
# [2988]	valid_0's auc: 0.998919	valid_0's binary_logloss: 0.0126728
# [2989]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126704
# [2990]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126713
# [2991]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126751
# [2992]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.012676
# [2993]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126812
# [2994]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126819
# [2995]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126873
# [2996]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0126917
# [2997]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126898
# [2998]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126904
# [2999]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126916
# [3000]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0126917
# [3001]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0126982
# [3002]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.012703
# [3003]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.012704
# [3004]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127079
# [3005]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127101
# [3006]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127135
# [3007]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127214
# [3008]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127316
# [3009]	valid_0's auc: 0.99892	valid_0's binary_logloss: 0.0127338
# [3010]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127386
# [3011]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127398
# [3012]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127426
# [3013]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127454
# [3014]	valid_0's auc: 0.998921	valid_0's binary_logloss: 0.0127469
# [3015]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0127578
# [3016]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.0127595
# [3017]	valid_0's auc: 0.998922	valid_0's binary_logloss: 0.012766
# [3018]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0127719
# [3019]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0127714
# [3020]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0127805
# [3021]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0127811
# [3022]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0127884
# [3023]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0127927
# [3024]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0127941
# [3025]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0127914
# [3026]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.012798
# [3027]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0127971
# [3028]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0127998
# [3029]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0128045
# [3030]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0128022
# [3031]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0128055
# [3032]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0128143
# [3033]	valid_0's auc: 0.998923	valid_0's binary_logloss: 0.0128187
# [3034]	valid_0's auc: 0.998924	valid_0's binary_logloss: 0.0128241
# Early stopping, best iteration is:
# [1034]	valid_0's auc: 0.998637	valid_0's binary_logloss: 0.00827669
# LGBMClassifier(is_unbalance=True, learning_rate=0.088, min_child_samples=30,
#                min_data_in_leaf=15, n_estimators=4000, num_leaves=100)

# %%
# 평가
y_pred = lgb.predict(df_test_x, num_iteration=lgb.best_iteration_)
# y_pred = lgb.predict(df_test_x, num_iteration=1306)
print("Accuracy: {0:.3f}\n".format(lgb.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.997
#
#               precision    recall  f1-score   support
#
#      class 0     0.9990    0.9984    0.9987    451928
#      class 1     0.8090    0.8759    0.8411      3602
#
#     accuracy                         0.9974    455530
#    macro avg     0.9040    0.9371    0.9199    455530
# weighted avg     0.9975    0.9974    0.9974    455530
#
# Confusion matrix:
# [[451183    745]
#  [   447   3155]]

# %%
# 변수 중요도 출력
fig, ax = plt.subplots(figsize=(12, 8))
plot_importance(lgb, ax = ax)

# %% [markdown]
# ### SMOTE + ENN 샘플링 적용 + is_unbalane 미적용
#
# ### Accuracy : 99.7% / Precision : 80.88% / Recall : 87.95% / F1-score : 84.27%

# %%
lgb = LGBMClassifier(n_estimators = 4000, min_data_in_leaf=15, num_leaves=100, learning_rate=0.088, min_child_samples=30)
evals = [(df_test_x, df_test_y)]
lgb.fit(df_train_x_over, df_train_y_over, early_stopping_rounds = 2000, eval_metric = "AUC", eval_set = evals, verbose = True)
# Out:
# y_logloss: 0.0117188
# [2588]	valid_0's auc: 0.998876	valid_0's binary_logloss: 0.011727
# [2589]	valid_0's auc: 0.998876	valid_0's binary_logloss: 0.0117309
# [2590]	valid_0's auc: 0.998876	valid_0's binary_logloss: 0.0117302
# [2591]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117342
# [2592]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117364
# [2593]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117379
# [2594]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117429
# [2595]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117477
# [2596]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117483
# [2597]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117554
# [2598]	valid_0's auc: 0.998877	valid_0's binary_logloss: 0.0117575
# [2599]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117614
# [2600]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117609
# [2601]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117625
# [2602]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117654
# [2603]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117667
# [2604]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.011776
# [2605]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117814
# [2606]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117856
# [2607]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117865
# [2608]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0117884
# [2609]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.011788
# [2610]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0117909
# [2611]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0117906
# [2612]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0117946
# [2613]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0117931
# [2614]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0117939
# [2615]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0117956
# [2616]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.011801
# [2617]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118035
# [2618]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118046
# [2619]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118073
# [2620]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118099
# [2621]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118109
# [2622]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118143
# [2623]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118173
# [2624]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118195
# [2625]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118193
# [2626]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118255
# [2627]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118289
# [2628]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.011827
# [2629]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118288
# [2630]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118323
# [2631]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118344
# [2632]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0118405
# [2633]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0118416
# [2634]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0118452
# [2635]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0118432
# [2636]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.011844
# [2637]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.011844
# [2638]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118482
# [2639]	valid_0's auc: 0.998882	valid_0's binary_logloss: 0.0118486
# [2640]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118576
# [2641]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118586
# [2642]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118617
# [2643]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118646
# [2644]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118652
# [2645]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0118698
# [2646]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.01187
# [2647]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118807
# [2648]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118799
# [2649]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.011882
# [2650]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0118869
# [2651]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119001
# [2652]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119121
# [2653]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119139
# [2654]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119144
# [2655]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119146
# [2656]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119142
# [2657]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119156
# [2658]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119166
# [2659]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119177
# [2660]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119221
# [2661]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119247
# [2662]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119272
# [2663]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119316
# [2664]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119339
# [2665]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0119446
# [2666]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119457
# [2667]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119471
# [2668]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.011958
# [2669]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0119584
# [2670]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0119645
# [2671]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0119665
# [2672]	valid_0's auc: 0.998878	valid_0's binary_logloss: 0.0119696
# [2673]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119716
# [2674]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119707
# [2675]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.011969
# [2676]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119743
# [2677]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.01198
# [2678]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119805
# [2679]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119834
# [2680]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.011986
# [2681]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119887
# [2682]	valid_0's auc: 0.998879	valid_0's binary_logloss: 0.0119921
# [2683]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119948
# [2684]	valid_0's auc: 0.99888	valid_0's binary_logloss: 0.0119966
# [2685]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0120004
# [2686]	valid_0's auc: 0.998882	valid_0's binary_logloss: 0.0120018
# [2687]	valid_0's auc: 0.998881	valid_0's binary_logloss: 0.0120065
# [2688]	valid_0's auc: 0.998882	valid_0's binary_logloss: 0.0120079
# [2689]	valid_0's auc: 0.998882	valid_0's binary_logloss: 0.0120131
# [2690]	valid_0's auc: 0.998882	valid_0's binary_logloss: 0.0120137
# [2691]	valid_0's auc: 0.998883	valid_0's binary_logloss: 0.0120144
# [2692]	valid_0's auc: 0.998883	valid_0's binary_logloss: 0.0120131
# [2693]	valid_0's auc: 0.998883	valid_0's binary_logloss: 0.0120143
# [2694]	valid_0's auc: 0.998883	valid_0's binary_logloss: 0.0120158
# [2695]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.0120203
# [2696]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.0120204
# [2697]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.0120296
# [2698]	valid_0's auc: 0.998883	valid_0's binary_logloss: 0.0120297
# [2699]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.01203
# [2700]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.0120341
# [2701]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120322
# [2702]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.012036
# [2703]	valid_0's auc: 0.998884	valid_0's binary_logloss: 0.0120379
# [2704]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120399
# [2705]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120425
# [2706]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120447
# [2707]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120458
# [2708]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120442
# [2709]	valid_0's auc: 0.998885	valid_0's binary_logloss: 0.0120462
# [2710]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120532
# [2711]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120589
# [2712]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.012059
# [2713]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120593
# [2714]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120601
# [2715]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120695
# [2716]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120769
# [2717]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120906
# [2718]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120931
# [2719]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120932
# [2720]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120923
# [2721]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120919
# [2722]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120924
# [2723]	valid_0's auc: 0.998886	valid_0's binary_logloss: 0.0120933
# [2724]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120948
# [2725]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120945
# [2726]	valid_0's auc: 0.998887	valid_0's binary_logloss: 0.0120994
# [2727]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0120986
# [2728]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0120979
# [2729]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0120993
# [2730]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0121147
# [2731]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121146
# [2732]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121178
# [2733]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121187
# [2734]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121253
# [2735]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121303
# [2736]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0121341
# [2737]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0121358
# [2738]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121345
# [2739]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121372
# [2740]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121403
# [2741]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121417
# [2742]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121429
# [2743]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121442
# [2744]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.012147
# [2745]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121507
# [2746]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121503
# [2747]	valid_0's auc: 0.998888	valid_0's binary_logloss: 0.0121556
# [2748]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121553
# [2749]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121572
# [2750]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121623
# [2751]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121648
# [2752]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121647
# [2753]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121701
# [2754]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121716
# [2755]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.012176
# [2756]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121797
# [2757]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121815
# [2758]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121803
# [2759]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121831
# [2760]	valid_0's auc: 0.998889	valid_0's binary_logloss: 0.0121831
# [2761]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121858
# [2762]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121878
# [2763]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.012189
# [2764]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121917
# [2765]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121933
# [2766]	valid_0's auc: 0.998891	valid_0's binary_logloss: 0.0121925
# [2767]	valid_0's auc: 0.998891	valid_0's binary_logloss: 0.0121936
# [2768]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121988
# [2769]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0121987
# [2770]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0122011
# [2771]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.012204
# [2772]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0122059
# [2773]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0122104
# [2774]	valid_0's auc: 0.998891	valid_0's binary_logloss: 0.0122091
# [2775]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0122135
# [2776]	valid_0's auc: 0.99889	valid_0's binary_logloss: 0.0122167
# [2777]	valid_0's auc: 0.998891	valid_0's binary_logloss: 0.0122159
# [2778]	valid_0's auc: 0.998891	valid_0's binary_logloss: 0.0122253
# [2779]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.012225
# [2780]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122265
# [2781]	valid_0's auc: 0.998893	valid_0's binary_logloss: 0.0122321
# [2782]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.012241
# [2783]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122418
# [2784]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122446
# [2785]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122466
# [2786]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122456
# [2787]	valid_0's auc: 0.998893	valid_0's binary_logloss: 0.0122453
# [2788]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122484
# [2789]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122481
# [2790]	valid_0's auc: 0.998892	valid_0's binary_logloss: 0.0122513
# [2791]	valid_0's auc: 0.998893	valid_0's binary_logloss: 0.0122526
# [2792]	valid_0's auc: 0.998893	valid_0's binary_logloss: 0.0122562
# [2793]	valid_0's auc: 0.998894	valid_0's binary_logloss: 0.0122559
# [2794]	valid_0's auc: 0.998894	valid_0's binary_logloss: 0.0122558
# [2795]	valid_0's auc: 0.998894	valid_0's binary_logloss: 0.0122606
# [2796]	valid_0's auc: 0.998895	valid_0's binary_logloss: 0.0122598
# [2797]	valid_0's auc: 0.998895	valid_0's binary_logloss: 0.0122591
# [2798]	valid_0's auc: 0.998895	valid_0's binary_logloss: 0.0122628
# [2799]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0122638
# [2800]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0122634
# [2801]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0122683
# [2802]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0122677
# [2803]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122701
# [2804]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122696
# [2805]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0122726
# [2806]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0122737
# [2807]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0122741
# [2808]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0122728
# [2809]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.012276
# [2810]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122815
# [2811]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122828
# [2812]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122822
# [2813]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122845
# [2814]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122873
# [2815]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0122916
# [2816]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0122991
# [2817]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123024
# [2818]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.012304
# [2819]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123043
# [2820]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123145
# [2821]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123139
# [2822]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123148
# [2823]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123213
# [2824]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.012323
# [2825]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123262
# [2826]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123276
# [2827]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.012331
# [2828]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123342
# [2829]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123411
# [2830]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123422
# [2831]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123451
# [2832]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123439
# [2833]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0123455
# [2834]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.012357
# [2835]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123661
# [2836]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123675
# [2837]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123682
# [2838]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123687
# [2839]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123698
# [2840]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.012378
# [2841]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123802
# [2842]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123858
# [2843]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123893
# [2844]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0123881
# [2845]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123977
# [2846]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123996
# [2847]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123979
# [2848]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123981
# [2849]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0123986
# [2850]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124027
# [2851]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0124041
# [2852]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124095
# [2853]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124181
# [2854]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124197
# [2855]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124237
# [2856]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124264
# [2857]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.012428
# [2858]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124315
# [2859]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124298
# [2860]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0124328
# [2861]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.012437
# [2862]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124414
# [2863]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124452
# [2864]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124477
# [2865]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124497
# [2866]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124543
# [2867]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124549
# [2868]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124538
# [2869]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.012461
# [2870]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124637
# [2871]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.012466
# [2872]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.01247
# [2873]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124708
# [2874]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124754
# [2875]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124773
# [2876]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124783
# [2877]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124784
# [2878]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.012479
# [2879]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0124783
# [2880]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0124785
# [2881]	valid_0's auc: 0.998896	valid_0's binary_logloss: 0.0124867
# [2882]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0124915
# [2883]	valid_0's auc: 0.998897	valid_0's binary_logloss: 0.0124933
# [2884]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0124939
# [2885]	valid_0's auc: 0.998898	valid_0's binary_logloss: 0.0124933
# Early stopping, best iteration is:
# [885]	valid_0's auc: 0.99858	valid_0's binary_logloss: 0.0083153
# LGBMClassifier(learning_rate=0.088, min_child_samples=30, min_data_in_leaf=15,
#                n_estimators=4000, num_leaves=100)

# %%
# 평가
y_pred = lgb.predict(df_test_x, num_iteration=lgb.best_iteration_)
# y_pred = lgb.predict(df_test_x, num_iteration=1306)
print("Accuracy: {0:.3f}\n".format(lgb.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.997
#
#               precision    recall  f1-score   support
#
#      class 0     0.9990    0.9983    0.9987    451928
#      class 1     0.8088    0.8795    0.8427      3602
#
#     accuracy                         0.9974    455530
#    macro avg     0.9039    0.9389    0.9207    455530
# weighted avg     0.9975    0.9974    0.9975    455530
#
# Confusion matrix:
# [[451179    749]
#  [   434   3168]]

# %%
# 변수 중요도 출력
fig, ax = plt.subplots(figsize=(12, 8))
plot_importance(lgb, ax = ax)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### SMOTE + ENN 미적용
#
# ### Accuracy : 99.2% / Precision : 48.25% / Recall : 50.44% / F1-score : 49.32%

# %%
tree_final = DecisionTreeClassifier()
tree_final.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier()

# %%
# 평가
y_pred = tree_final.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(tree_final.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.992
#
#               precision    recall  f1-score   support
#
#      class 0     0.9960    0.9957    0.9959    451928
#      class 1     0.4825    0.5044    0.4932      3602
#
#     accuracy                         0.9918    455530
#    macro avg     0.7393    0.7501    0.7445    455530
# weighted avg     0.9920    0.9918    0.9919    455530
#
# Confusion matrix:
# [[449979   1949]
#  [  1785   1817]]

# %% [markdown]
# ### SMOTE + ENN 적용
#
# ### Accuracy : 99.5% / Precision : 63.02% / Recall : 86.09% / F1-score : 72.77%

# %%
tree_final = DecisionTreeClassifier()
tree_final.fit(df_train_x_over, df_train_y_over)
# Out:
# DecisionTreeClassifier()

# %%
# 평가
y_pred = tree_final.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(tree_final.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.995
#
#               precision    recall  f1-score   support
#
#      class 0     0.9989    0.9960    0.9974    451928
#      class 1     0.6302    0.8609    0.7277      3602
#
#     accuracy                         0.9949    455530
#    macro avg     0.8145    0.9284    0.8626    455530
# weighted avg     0.9960    0.9949    0.9953    455530
#
# Confusion matrix:
# [[450108   1820]
#  [   501   3101]]

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### SMOTE + ENN 미적용
#
# ### Accuracy : 99.4% / Precision : 77.39% / Recall : 33.06% / F1-score : 46.33%

# %%
from sklearn.ensemble import RandomForestClassifier

rf_uncustomized = RandomForestClassifier()
rf_uncustomized.fit(df_train_x, df_train_y)
# Out:
# RandomForestClassifier()

# %%
# 평가
y_pred = rf_uncustomized.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(rf_uncustomized.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.994
#
#               precision    recall  f1-score   support
#
#      class 0     0.9947    0.9992    0.9970    451928
#      class 1     0.7739    0.3306    0.4633      3602
#
#     accuracy                         0.9939    455530
#    macro avg     0.8843    0.6649    0.7301    455530
# weighted avg     0.9929    0.9939    0.9927    455530
#
# Confusion matrix:
# [[451580    348]
#  [  2411   1191]]

# %% [markdown]
# ### SMOTE + ENN 적용
#
# ### Accuracy : 99.6% / Precision : 73.38% / Recall : 86.31% / F1-score : 79.32%

# %%
from sklearn.ensemble import RandomForestClassifier

rf_uncustomized = RandomForestClassifier()
rf_uncustomized.fit(df_train_x_over, df_train_y_over)
# Out:
# RandomForestClassifier()

# %%
# 평가
y_pred = rf_uncustomized.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(rf_uncustomized.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.996
#
#               precision    recall  f1-score   support
#
#      class 0     0.9989    0.9975    0.9982    451928
#      class 1     0.7338    0.8631    0.7932      3602
#
#     accuracy                         0.9964    455530
#    macro avg     0.8663    0.9303    0.8957    455530
# weighted avg     0.9968    0.9964    0.9966    455530
#
# Confusion matrix:
# [[450800   1128]
#  [   493   3109]]

# %% [markdown]
# ## Gradient Boosting 적용

# %% [markdown]
# ### SMOTE + ENN 미적용
#
# ### Accuracy : 99.3% / Precision : 69.65% / Recall : 18.99% / F1-score : 29.84%

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_final = GradientBoostingClassifier(n_estimators = 100, learning_rate = 0.09)
gb_final.fit(df_train_x, df_train_y)
# Out:
# GradientBoostingClassifier(learning_rate=0.09)

# %%
# 평가
y_pred = gb_final.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(gb_final.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.993
#
#               precision    recall  f1-score   support
#
#      class 0     0.9936    0.9993    0.9965    451928
#      class 1     0.6965    0.1899    0.2984      3602
#
#     accuracy                         0.9929    455530
#    macro avg     0.8451    0.5946    0.6474    455530
# weighted avg     0.9912    0.9929    0.9909    455530
#
# Confusion matrix:
# [[451630    298]
#  [  2918    684]]

# %% [markdown]
# ### SMOTE + ENN 적용
#
# ### Accuracy : 96.5% / Precision : 17.33% / Recall : 89.76% / F1-score : 29.06%

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_final = GradientBoostingClassifier(n_estimators = 100, learning_rate = 0.09)
gb_final.fit(df_train_x_over, df_train_y_over)
# Out:
# GradientBoostingClassifier(learning_rate=0.09)

# %%
# 평가
y_pred = gb_final.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(gb_final.score(df_test_x, df_test_y)))
print(classification_report(df_test_y, y_pred, target_names=['class 0', 'class 1'], digits=4))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.965
#
#               precision    recall  f1-score   support
#
#      class 0     0.9992    0.9659    0.9822    451928
#      class 1     0.1733    0.8976    0.2906      3602
#
#     accuracy                         0.9653    455530
#    macro avg     0.5862    0.9317    0.6364    455530
# weighted avg     0.9926    0.9653    0.9768    455530
#
# Confusion matrix:
# [[436509  15419]
#  [   369   3233]]
